# %%
# load libraries
library(data.table)
library(dplyr)
library(tidyverse)
library(ggplot2)
library(gridExtra)

# %%
# set paths
results_dir = "/space/syn50/1/data/ABCD/d9smith/random_effects/results_2023-03-03/designMat02_t1w_AgeSexScanSoft/FASE/"
savepath = "/home/d9smith/projects/random_effects/plots/results_2023-03-03/FASE/"

# %%
# load data
filenames = list.files(path = results_dir, pattern = "*.csv")

for (fname in filenames) {
    pheno = str_split(fname, "_")[[1]][1]
    rand = str_split(str_split(fname, "_")[[1]][5],".csv")[[1]][1]
    vname = paste(pheno, rand, sep='_')
    
    df = read.table(paste(results_dir, fname, sep=""), sep=',', header=TRUE)
    df$rand = rand
    df$rand = ifelse(df$rand=="F", "C", df$rand) # change F to C for ease of interpretation
    df$rand = factor(df$rand, levels = c("A", "C", "S", "E"))

    # fix labels of regions
    df$Label = strsplit(as.character(df$Label),"-")
    
    for (i in 1:length(df$Label)) {
        df$Label_combined[i] = df$Label[i][[1]][2]
        df$Label[i] = paste(rev(df$Label[i][[1]]),collapse=" ")
    }
    
    df$Label = unlist(df$Label)
    
    # save as dataframe
    assign(vname, df) 
}
# Out:
#       Stats                   Label rand
# 1 0.3034440           lh-precentral    A
# 2 0.4122570     lh-superiorparietal    A
# 3 0.5478263      lh-superiorfrontal    A
# 4 0.4020990 lh-rostralmiddlefrontal    A
# 5 0.3694112           lh-precentral    A
# 6 0.3074005        lh-supramarginal    A
#       Stats                   Label rand
# 1 0.3034440           lh-precentral    A
# 2 0.4122570     lh-superiorparietal    A
# 3 0.5478263      lh-superiorfrontal    A
# 4 0.4020990 lh-rostralmiddlefrontal    A
# 5 0.3694112           lh-precentral    A
# 6 0.3074005        lh-supramarginal    A
#        Stats                   Label rand
# 1 0.07888822           lh-precentral    E
# 2 0.05577823     lh-superiorparietal    E
# 3 0.05266425      lh-superiorfrontal    E
# 4 0.05600434 lh-rostralmiddlefrontal    E
# 5 0.05005444           lh-precentral    E
# 6 0.06195192        lh-supramarginal    E
#        Stats                   Label rand
# 1 0.07888822           lh-precentral    E
# 2 0.05577823     lh-superiorparietal    E
# 3 0.05266425      lh-superiorfrontal    E
# 4 0.05600434 lh-rostralmiddlefrontal    E
# 5 0.05005444           lh-precentral    E
# 6 0.06195192        lh-supramarginal    E
#        Stats                   Label rand
# 1 0.16688467           lh-precentral    C
# 2 0.16581435     lh-superiorparietal    C
# 3 0.08821328      lh-superiorfrontal    C
# 4 0.12557040 lh-rostralmiddlefrontal    C
# 5 0.13309426           lh-precentral    C
# 6 0.04618327        lh-supramarginal    C
#        Stats                   Label rand
# 1 0.16688467           lh-precentral    C
# 2 0.16581435     lh-superiorparietal    C
# 3 0.08821328      lh-superiorfrontal    C
# 4 0.12557040 lh-rostralmiddlefrontal    C
# 5 0.13309426           lh-precentral    C
# 6 0.04618327        lh-supramarginal    C
#       Stats                   Label rand
# 1 0.4507831           lh-precentral    S
# 2 0.3661505     lh-superiorparietal    S
# 3 0.3112961      lh-superiorfrontal    S
# 4 0.4163263 lh-rostralmiddlefrontal    S
# 5 0.4474401           lh-precentral    S
# 6 0.5844643        lh-supramarginal    S
#       Stats                   Label rand
# 1 0.4507831           lh-precentral    S
# 2 0.3661505     lh-superiorparietal    S
# 3 0.3112961      lh-superiorfrontal    S
# 4 0.4163263 lh-rostralmiddlefrontal    S
# 5 0.4474401           lh-precentral    S
# 6 0.5844643        lh-supramarginal    S
#       Stats                   Label rand
# 1 0.2977188           lh-precentral    A
# 2 0.1857168     lh-superiorparietal    A
# 3 0.2709171      lh-superiorfrontal    A
# 4 0.1224576 lh-rostralmiddlefrontal    A
# 5 0.2397538           lh-precentral    A
# 6 0.1253208        lh-supramarginal    A
#       Stats                   Label rand
# 1 0.2977188           lh-precentral    A
# 2 0.1857168     lh-superiorparietal    A
# 3 0.2709171      lh-superiorfrontal    A
# 4 0.1224576 lh-rostralmiddlefrontal    A
# 5 0.2397538           lh-precentral    A
# 6 0.1253208        lh-supramarginal    A
#        Stats                   Label rand
# 1 0.17902611           lh-precentral    E
# 2 0.05079131     lh-superiorparietal    E
# 3 0.06002785      lh-superiorfrontal    E
# 4 0.06349180 lh-rostralmiddlefrontal    E
# 5 0.06242289           lh-precentral    E
# 6 0.04057470        lh-supramarginal    E
#        Stats                   Label rand
# 1 0.17902611           lh-precentral    E
# 2 0.05079131     lh-superiorparietal    E
# 3 0.06002785      lh-superiorfrontal    E
# 4 0.06349180 lh-rostralmiddlefrontal    E
# 5 0.06242289           lh-precentral    E
# 6 0.04057470        lh-supramarginal    E
#          Stats                   Label rand
# 1 2.084065e-07           lh-precentral    C
# 2 1.375665e-01     lh-superiorparietal    C
# 3 4.527484e-02      lh-superiorfrontal    C
# 4 6.231003e-02 lh-rostralmiddlefrontal    C
# 5 5.948377e-02           lh-precentral    C
# 6 9.203060e-02        lh-supramarginal    C
#          Stats                   Label rand
# 1 2.084065e-07           lh-precentral    C
# 2 1.375665e-01     lh-superiorparietal    C
# 3 4.527484e-02      lh-superiorfrontal    C
# 4 6.231003e-02 lh-rostralmiddlefrontal    C
# 5 5.948377e-02           lh-precentral    C
# 6 9.203060e-02        lh-supramarginal    C
#       Stats                   Label rand
# 1 0.5232549           lh-precentral    S
# 2 0.6259254     lh-superiorparietal    S
# 3 0.6237802      lh-superiorfrontal    S
# 4 0.7517406 lh-rostralmiddlefrontal    S
# 5 0.6383396           lh-precentral    S
# 6 0.7420739        lh-supramarginal    S
#       Stats                   Label rand
# 1 0.5232549           lh-precentral    S
# 2 0.6259254     lh-superiorparietal    S
# 3 0.6237802      lh-superiorfrontal    S
# 4 0.7517406 lh-rostralmiddlefrontal    S
# 5 0.6383396           lh-precentral    S
# 6 0.7420739        lh-supramarginal    S
#       Stats                   Label rand
# 1 0.3280620           lh-precentral    A
# 2 0.3037710     lh-superiorparietal    A
# 3 0.2800450      lh-superiorfrontal    A
# 4 0.3650131 lh-rostralmiddlefrontal    A
# 5 0.3945231           lh-precentral    A
# 6 0.2718177        lh-supramarginal    A
#       Stats                   Label rand
# 1 0.3280620           lh-precentral    A
# 2 0.3037710     lh-superiorparietal    A
# 3 0.2800450      lh-superiorfrontal    A
# 4 0.3650131 lh-rostralmiddlefrontal    A
# 5 0.3945231           lh-precentral    A
# 6 0.2718177        lh-supramarginal    A
#       Stats                   Label rand
# 1 0.2732819           lh-precentral    E
# 2 0.2513349     lh-superiorparietal    E
# 3 0.1671048      lh-superiorfrontal    E
# 4 0.2870719 lh-rostralmiddlefrontal    E
# 5 0.1569599           lh-precentral    E
# 6 0.2416430        lh-supramarginal    E
#       Stats                   Label rand
# 1 0.2732819           lh-precentral    E
# 2 0.2513349     lh-superiorparietal    E
# 3 0.1671048      lh-superiorfrontal    E
# 4 0.2870719 lh-rostralmiddlefrontal    E
# 5 0.1569599           lh-precentral    E
# 6 0.2416430        lh-supramarginal    E
#        Stats                   Label rand
# 1 0.11409807           lh-precentral    C
# 2 0.10493806     lh-superiorparietal    C
# 3 0.17636919      lh-superiorfrontal    C
# 4 0.07918989 lh-rostralmiddlefrontal    C
# 5 0.06356120           lh-precentral    C
# 6 0.12418621        lh-supramarginal    C
#        Stats                   Label rand
# 1 0.11409807           lh-precentral    C
# 2 0.10493806     lh-superiorparietal    C
# 3 0.17636919      lh-superiorfrontal    C
# 4 0.07918989 lh-rostralmiddlefrontal    C
# 5 0.06356120           lh-precentral    C
# 6 0.12418621        lh-supramarginal    C
#       Stats                   Label rand
# 1 0.2845580           lh-precentral    S
# 2 0.3399561     lh-superiorparietal    S
# 3 0.3764810      lh-superiorfrontal    S
# 4 0.2687251 lh-rostralmiddlefrontal    S
# 5 0.3849558           lh-precentral    S
# 6 0.3623531        lh-supramarginal    S
#       Stats                   Label rand
# 1 0.2845580           lh-precentral    S
# 2 0.3399561     lh-superiorparietal    S
# 3 0.3764810      lh-superiorfrontal    S
# 4 0.2687251 lh-rostralmiddlefrontal    S
# 5 0.3849558           lh-precentral    S
# 6 0.3623531        lh-supramarginal    S

# %%
# combine into one dataframe per phenotype
area = rbind(area_A, area_F, area_S)
thickness = rbind(thickness_A, thickness_F, thickness_S)
sulc = rbind(sulc_A, sulc_F, sulc_S)

# %%
# Function to create plots
plot_roi <- function(df, label='Label') {

    ggplot(na.omit(df), aes(x=na.omit(df)[,label], y=Stats)) + 
    geom_violin(width=2, size=0.2) + 
    stat_summary(fun = "mean", geom="point", shape=1, size=0.2)+
    coord_flip() +
    xlab("") +
    ylab("Proportion of Variance")+
    facet_wrap( ~ rand, nrow = 1)+
    theme_bw()+
    theme(axis.text.y = element_text(size=6))
}

# %%
plot_area = plot_roi(area, label = 'Label_combined')

# %%
plot_thickness = plot_roi(thickness, label = 'Label_combined')

# %%
plot_sulc = plot_roi(sulc, label = 'Label_combined')

# %%
plot_area
plot_thickness
plot_sulc
# Out:
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# plot without title
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# plot without title
# plot without title

# %%
# Function to view means by region - note this is hard-coded to sort by "Label_combined"
summary_roi <- function(df, rand) {
    df[df$rand==rand,] %>%
    group_by(Label_combined) %>%
    summarise(mean = mean(Stats)) %>%
    arrange(mean)
}

# %%
summary_roi(sulc, 'S'); 

# summary_roi(thickness); summary_roi(area); summary_roi(sulc)
# cbind(summary_roi(thickness), summary_roi(area), summary_roi(sulc))
# Out:
#    Label_combined           mean
# 1  NA                       0.0000000
# 2  temporalpole             0.3370236
# 3  insula                   0.3612109
# 4  entorhinal               0.4074366
# 5  medialorbitofrontal      0.4206561
# 6  frontalpole              0.4543468
# 7  lateralorbitofrontal     0.4564349
# 8  isthmuscingulate         0.4613542
# 9  pericalcarine            0.4654406
# 10 transversetemporal       0.4782471
# 11 cuneus                   0.4782671
# 12 parahippocampal          0.5028193
# 13 lingual                  0.5101434
# 14 posteriorcingulate       0.5320603
# 15 rostralanteriorcingulate 0.5324788
# 16 parsorbitalis            0.5406296
# 17 lateraloccipital         0.5447156
# 18 superiortemporal         0.5475397
# 19 postcentral              0.5608287
# 20 precuneus                0.5626167
# 21 fusiform                 0.5634318
# 22 paracentral              0.5792365
# 23 parstriangularis         0.5811480
# 24 caudalanteriorcingulate  0.6072661
# 25 precentral               0.6115447
# 26 parsopercularis          0.6337848
# 27 inferiortemporal         0.6355517
# 28 supramarginal            0.6530054
# 29 rostralmiddlefrontal     0.6533967
# 30 superiorparietal         0.6550997
# 31 superiorfrontal          0.6571062
# 32 middletemporal           0.6669122
# 33 bankssts                 0.6933411
# 34 inferiorparietal         0.6968902
# 35 caudalmiddlefrontal      0.7375829

# %%
ggsave(plot_area, file = paste(savepath,'area_ROI.eps',sep=""))
ggsave(plot_thickness, file = paste(savepath,'thickness_ROI.eps',sep=""))
ggsave(plot_sulc, file = paste(savepath,'sulc_ROI.eps',sep=""))
# Out:
# Saving 6.67 x 6.67 in image
#
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# Saving 6.67 x 6.67 in image
#
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# Saving 6.67 x 6.67 in image
#
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# Warning message:
# “position_dodge requires non-overlapping x intervals”
# Warning message:
# “position_dodge requires non-overlapping x intervals”
