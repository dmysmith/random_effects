# %%
install.packages("Hmisc")
# Out:
# Installing package into ‘/home/d9smith/R/x86_64-pc-linux-gnu-library/3.6’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘deldir’, ‘jpeg’, ‘interp’, ‘checkmate’, ‘Formula’, ‘latticeExtra’, ‘htmlTable’

# %%
library(Hmisc)
# Out:
# Loading required package: lattice
#
# Loading required package: survival
#
# Loading required package: Formula
#
# Loading required package: ggplot2
#
#
# Attaching package: ‘Hmisc’
#
#
# The following objects are masked from ‘package:base’:
#
#     format.pval, units

# %%
phenopath <- '/space/syn50/1/data/ABCD/d9smith/random_effects/behavioral/data/pheno'

baseline_fname <- 'baseline_unadjusted.txt'
longitudinal_fname <- 'longitudinal_unadjusted.txt'

baseline <- read.table(paste0(phenopath, '/', baseline_fname), header = T)
longitudinal <- read.table(paste0(phenopath, '/', longitudinal_fname), header = T)

# baseline_phenos <- read.table(paste0(phenopath, '/', 'baseline_phenonames.txt'))
# y2_phenos <- read.table(paste0(phenopath, '/', 'longitudinal_phenonames.txt'))

baseline_phenos <- scan(paste0(phenopath, '/', 'baseline_phenonames.txt'), what="", sep="\n")
baseline_phenos <- baseline_phenos[2:length(baseline_phenos)]

y2_phenos <- scan(paste0(phenopath, '/', 'longitudinal_phenonames.txt'), what="", sep="\n")
y2_phenos <- y2_phenos[2:length(y2_phenos)]

# %% [markdown]
# # Inspecting Baseline data

# %%
hist.data.frame(baseline, rugs = T)
# Out:
# Plot with title “”

# %%
hist(baseline$anthroheightcalc, breaks = 80)
rug(baseline$anthroheightcalc)
# Out:
# Plot with title “Histogram of baseline$anthroheightcalc”

# %% [markdown]
# # Inspecting Longitudinal Data

# %%
hist.data.frame(longitudinal, rugs = T)
# Out:
# Plot with title “”

# %%
hist(longitudinal$anthroheightcalc, breaks = 80)
rug(longitudinal$anthroheightcalc)
# Out:
# Plot with title “Histogram of longitudinal$anthroheightcalc”
